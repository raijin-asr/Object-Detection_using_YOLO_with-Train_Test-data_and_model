# %% [markdown]
# # Training

# %%
from ultralytics import YOLO
import os  # Import the os module

# Get the directory where the code is executed
current_dir = os.getcwd()

# Load a model
model = YOLO("yolov8n.pt")  # Load the YOLOv8n model

data_path= current_dir + r"\data\Car_Bike_Person_Bicycle-Datasets\data.yaml"
save_path= current_dir + r"\object_results"

# print(save_path)

# Use the model
train_result = model.train(data=data_path, epochs=1, project=save_path)  # Train the model and save results to the specified directory
# Out:
# D:\PROJECTS\Python\Object Detection Project\object_results

# %%
import matplotlib.pyplot as plt

# trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/train/confusion_matrix.png"
trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/confusion_matrix.png"

# Load the image using Matplotlib
trained_image = plt.imread(trained_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(trained_image)
plt.axis('off')  # Hide axis
plt.show()

# %%
trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/results.png"

# Load the image using Matplotlib
trained_image = plt.imread(trained_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(trained_image)
plt.axis('off')  # Hide axis
plt.show()

# %%
trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/val_batch1_labels.jpg"

# Load the image using Matplotlib
trained_image = plt.imread(trained_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(trained_image)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# # Validation

# %%
model = YOLO(r'object_results/train/weights/best.pt')


# Evaluate the model's performance on the validation set
validation_results = model.val(data='config.yaml',project=r"object_results")

# %%
validated_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/val_batch1_labels.jpg"

# Load the image using Matplotlib
validated_image = plt.imread(validated_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(validated_image)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# # Prediction or Testing

# %%
#Prediction on test images
from ultralytics import YOLO
import cv2
import os  # Import the os module

# Get the directory where the code is executed
current_dir = os.getcwd()

# Load a model
model = YOLO("yolov8n.pt")  # Load the YOLOv8n model

# model_path= current_dir + r"\object_results\best.pt"

# model = YOLO(r'object_results/train/weights/best.pt')
# model = YOLO(model_path)

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()  # Capture frame from webcam
    
    if not ret:
        print("Error: Failed to capture frame")
        break

    # Predict objects on the frame
    predict_results = model.predict(frame, show=True)

    # Check for 'q' key press to close camera
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close OpenCV windows
cap.release()
cv2.destroyAllWindows()()
# Out:
# 0: 480x640 1 person, 1 refrigerator, 204.2ms
# Speed: 8.8ms preprocess, 204.2ms inference, 1530.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 159.7ms
# Speed: 0.0ms preprocess, 159.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 92.7ms
# Speed: 0.0ms preprocess, 92.7ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 110.9ms
# Speed: 2.6ms preprocess, 110.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 101.7ms
# Speed: 4.5ms preprocess, 101.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 1 refrigerator, 104.8ms
# Speed: 4.5ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 100.3ms
# Speed: 4.5ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 91.7ms
# Speed: 0.0ms preprocess, 91.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 93.6ms
# Speed: 5.5ms preprocess, 93.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 refrigerator, 70.0ms
# Speed: 2.4ms preprocess, 70.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 1 bed, 1 refrigerator, 91.4ms
# Speed: 0.0ms preprocess, 91.4ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[1], line 36
#      34 # Release the webcam and close OpenCV windows
#      35 cap.release()
# ---> 36 cv2.destroyAllWindows()()
#
# TypeError: 'NoneType' object is not callable

# %%
#Predicted test images
predicted_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/val_batch1_labels.jpg"

# Load the image using Matplotlib
predicted_image = plt.imread(predicted_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(predicted_image)
plt.axis('off')  # Hide axis
plt.show()
